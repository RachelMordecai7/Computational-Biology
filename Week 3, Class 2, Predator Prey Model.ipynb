# %% [markdown]
# # Predator-Prey Model

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 50000
a = 0.6
b = 1.2
c = 0.5
d = 1 #Resiliance of the fox 

dt = 0.001 #Accounts for smoothness of the graph

possible_ds = [0.5, 1, 1.5, 2] #Range of d values to run in the loop 

x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()

for itrial in range(len(possible_ds)):
    d = possible_ds[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1]) #Add [t-1] in the beginning 
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1])

#Figure 1
    ax1 = fig1.add_subplot(1,len(possible_ds),itrial+1)
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

#Figure 2
    ax2.plot(x,y, label=d);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
 
ax2.legend(loc='upper right');
